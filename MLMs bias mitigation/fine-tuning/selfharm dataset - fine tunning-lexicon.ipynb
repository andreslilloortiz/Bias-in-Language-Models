# %%
#import os
#os.environ["CUDA_DEVICE_ORDER"]="PCI_BUS_ID"
#os.environ["CUDA_VISIBLE_DEVICES"]="6"  # specify which GPU(s) to be used 6,7

# %%
# %pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu121
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121
# Requirement already satisfied: torch in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (2.5.1+cu121)
# Requirement already satisfied: torchvision in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (0.20.1+cu121)
# Requirement already satisfied: torchaudio in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (2.5.1+cu121)
# Requirement already satisfied: filelock in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (3.25.2)
# Requirement already satisfied: typing-extensions>=4.8.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (4.15.0)
# Requirement already satisfied: networkx in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (3.6.1)
# Requirement already satisfied: jinja2 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (2026.2.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (3.1.0)
# Requirement already satisfied: setuptools in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (70.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch) (12.9.86)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torchvision) (2.4.3)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torchvision) (12.1.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from jinja2->torch) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install transformers[torch] pandas datasets ipywidgets huggingface_hub
# Out:
# Requirement already satisfied: pandas in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (3.0.1)
# Requirement already satisfied: datasets in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (4.8.4)
# Requirement already satisfied: ipywidgets in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (8.1.8)
# Requirement already satisfied: huggingface_hub in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: transformers[torch] in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (5.4.0)
# Requirement already satisfied: numpy>=1.17 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from transformers[torch]) (2.4.3)
# Requirement already satisfied: packaging>=20.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from transformers[torch]) (26.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from transformers[torch]) (6.0.3)
# Requirement already satisfied: regex>=2025.10.22 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from transformers[torch]) (2026.3.32)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from transformers[torch]) (0.22.2)
# Requirement already satisfied: typer in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from transformers[torch]) (0.24.1)
# Requirement already satisfied: safetensors>=0.4.3 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from transformers[torch]) (0.7.0)
# Requirement already satisfied: tqdm>=4.27 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from transformers[torch]) (4.67.3)
# Requirement already satisfied: torch>=2.4 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from transformers[torch]) (2.5.1+cu121)
# Requirement already satisfied: accelerate>=1.1.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from transformers[torch]) (1.13.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: filelock in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from datasets) (3.25.2)
# Requirement already satisfied: pyarrow>=21.0.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from datasets) (23.0.1)
# Requirement already satisfied: dill<0.4.2,>=0.3.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from datasets) (0.4.1)
# Requirement already satisfied: requests>=2.32.2 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from datasets) (2.33.0)
# Requirement already satisfied: httpx<1.0.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from datasets) (0.28.1)
# Requirement already satisfied: xxhash in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from datasets) (3.6.0)
# Requirement already satisfied: multiprocess<0.70.20 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from datasets) (0.70.19)
# Requirement already satisfied: fsspec<=2026.2.0,>=2023.1.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2026.2.0)
# Requirement already satisfied: comm>=0.1.3 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from ipywidgets) (0.2.3)
# Requirement already satisfied: ipython>=6.1.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from ipywidgets) (9.12.0)
# Requirement already satisfied: traitlets>=4.3.1 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from ipywidgets) (5.14.3)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from ipywidgets) (4.0.15)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from ipywidgets) (3.0.16)
# Requirement already satisfied: hf-xet<2.0.0,>=1.4.2 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from huggingface_hub) (1.4.2)
# Requirement already satisfied: typing-extensions>=4.1.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: psutil in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from accelerate>=1.1.0->transformers[torch]) (7.2.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (3.13.4)
# Requirement already satisfied: anyio in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (4.13.0)
# Requirement already satisfied: certifi in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (2026.2.25)
# Requirement already satisfied: httpcore==1.* in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (1.0.9)
# Requirement already satisfied: idna in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from httpx<1.0.0->datasets) (3.11)
# Requirement already satisfied: h11>=0.16 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from httpcore==1.*->httpx<1.0.0->datasets) (0.16.0)
# Requirement already satisfied: decorator>=5.1.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (1.1.1)
# Requirement already satisfied: jedi>=0.18.2 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.6 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.2.1)
# Requirement already satisfied: pexpect>4.6 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (3.0.52)
# Requirement already satisfied: pygments>=2.14.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (2.20.0)
# Requirement already satisfied: stack_data>=0.6.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from ipython>=6.1.0->ipywidgets) (0.6.3)
# Requirement already satisfied: six>=1.5 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (3.4.6)
# Requirement already satisfied: urllib3<3,>=1.26 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from requests>=2.32.2->datasets) (2.6.3)
# Requirement already satisfied: networkx in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.6.1)
# Requirement already satisfied: jinja2 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.1.6)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (12.1.105)
# Requirement already satisfied: triton==3.1.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (3.1.0)
# Requirement already satisfied: setuptools in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (70.2.0)
# Requirement already satisfied: sympy==1.13.1 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from torch>=2.4->transformers[torch]) (1.13.1)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch>=2.4->transformers[torch]) (12.9.86)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from sympy==1.13.1->torch>=2.4->transformers[torch]) (1.3.0)
# Requirement already satisfied: click>=8.2.1 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from typer->transformers[torch]) (8.3.1)
# Requirement already satisfied: shellingham>=1.3.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from typer->transformers[torch]) (1.5.4)
# Requirement already satisfied: rich>=12.3.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from typer->transformers[torch]) (14.3.3)
# Requirement already satisfied: annotated-doc>=0.0.2 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from typer->transformers[torch]) (0.0.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2026.2.0,>=2023.1.0->datasets) (1.23.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from jedi>=0.18.2->ipython>=6.1.0->ipywidgets) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from pexpect>4.6->ipython>=6.1.0->ipywidgets) (0.7.0)
# Requirement already satisfied: wcwidth in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets) (0.6.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from rich>=12.3.0->typer->transformers[torch]) (4.0.0)
# Requirement already satisfied: executing>=1.2.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (3.0.1)
# Requirement already satisfied: pure-eval in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets) (0.2.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from jinja2->torch>=2.4->transformers[torch]) (3.0.3)
# Requirement already satisfied: mdurl~=0.1 in /home/andres/Documentos/Big Data/TFM/Lab/MLMs bias mitigation/.venv_MLMsbm/lib/python3.12/site-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer->transformers[torch]) (0.1.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

#torch.cuda.is_available()
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 2060'

# %% [markdown]
# # Load BERT model

# %%
from transformers import AutoModelForMaskedLM

model_checkpoint = "bert-base-uncased"
model = AutoModelForMaskedLM.from_pretrained(model_checkpoint)
# Out:
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# BertForMaskedLM LOAD REPORT from: bert-base-uncased
# Key                         | Status     |  |
# ----------------------------+------------+--+-
# cls.seq_relationship.bias   | UNEXPECTED |  |
# bert.pooler.dense.weight    | UNEXPECTED |  |
# bert.pooler.dense.bias      | UNEXPECTED |  |
# cls.seq_relationship.weight | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED:	can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
distilbert_num_parameters = model.num_parameters() / 1_000_000
print(f"'>>> BERT number of parameters: {round(distilbert_num_parameters)}M'")
# Out:
# '>>> BERT number of parameters: 110M'

# %% [markdown]
# ## Tokenize text example

# %%
text = "This is a great [MASK]."

# %%
from transformers import AutoTokenizer

tokenizer = AutoTokenizer.from_pretrained(model_checkpoint)

# %%
import torch

inputs = tokenizer(text, return_tensors="pt")
token_logits = model(**inputs).logits
# Find the location of [MASK] and extract its logits
mask_token_index = torch.where(inputs["input_ids"] == tokenizer.mask_token_id)[1]
mask_token_logits = token_logits[0, mask_token_index, :]
# Pick the [MASK] candidates with the highest logits
top_5_tokens = torch.topk(mask_token_logits, 5, dim=1).indices[0].tolist()

for token in top_5_tokens:
    print(f"'>>> {text.replace(tokenizer.mask_token, tokenizer.decode([token]))}'")
# Out:
# '>>> This is a great idea.'
# '>>> This is a great day.'
# '>>> This is a great place.'
# '>>> This is a great time.'
# '>>> This is a great thing.'

# %% [markdown]
# # Load dataset

# %%
import pandas as pd
from datasets import Dataset, load_dataset, concatenate_datasets

#Original
raw_dep_1 = pd.read_csv("../selfharm datasets/selfharm_1_neutral.csv", usecols = ['title'], encoding='unicode_escape')
raw_dep_1.rename(columns={"title": "post"}, inplace=True)
raw_dep_11 = pd.read_csv("../selfharm datasets/selfharm_1_neutral.csv",  usecols = ['body'], encoding='unicode_escape')
raw_dep_11.rename(columns={"body": "post"}, inplace=True)
dep_posts1 = raw_dep_1.dropna()
dep_posts11 = raw_dep_11.dropna()

raw_dep_2 = pd.read_csv("../selfharm datasets/selfharm_2_neutral.csv", usecols = ['title'], encoding='unicode_escape')
raw_dep_2.rename(columns={"title": "post"}, inplace=True)
raw_dep_22 = pd.read_csv("../selfharm datasets/selfharm_2_neutral.csv",  usecols = ['body'], encoding='unicode_escape')
raw_dep_22.rename(columns={"body": "post"}, inplace=True)
dep_posts2 = raw_dep_2.dropna()
dep_posts22 = raw_dep_22.dropna()

#### Augmented
column_names = ["post"]
aug_posts_raw1 = pd.read_csv("../selfharm datasets/selfharm_augmented_neutral.csv", names=column_names, skiprows=1)
aug_posts1 = aug_posts_raw1.dropna()

aug_posts_raw2 = pd.read_csv("../selfharm datasets/selfharm_augmented2_neutral.csv", names=column_names, skiprows=1)
aug_posts2 = aug_posts_raw2.dropna()

# Convert to dataset format
dataset1 = Dataset.from_pandas(dep_posts1)
dataset11 = Dataset.from_pandas(dep_posts11)
dataset2 = Dataset.from_pandas(dep_posts2)
dataset22 = Dataset.from_pandas(dep_posts22)

dataset3 = Dataset.from_pandas(aug_posts1)
dataset4 = Dataset.from_pandas(aug_posts2)

dataset = concatenate_datasets([dataset1, dataset11, dataset2, dataset22, dataset3, dataset4])
dataset
# Out:
# Dataset({
#     features: ['post', '__index_level_0__'],
#     num_rows: 64744
# })

# %%
sample = dataset.shuffle(seed=42).select(range(3))

for row in sample:
    print(f"\n'>>> Post: {row['post']}'")
# Out:
# '>>> Post: Hi, I'm 16 years old and I've been self-harming for two years. it started when I was in an abusive relationship and I was too scared to get out. when things finally ended after 6 months, I was clean for almost a year. I'm currently in a very healthy relationship with my partner, and I'm the happiest I've ever been with someone, we're about to hit 8 months and yesterday the streak broke. when I hurt myself, it's usually because of an argument with my parents and I feel the need to punish myself out of guilt, or if I've built anger I take it on myself. I know that if my parents find out that I'm just telling me that I'm being dramatic and I just want attention, but self-harm makes me feel much better and I really need it. I came here looking for tips because I want to improve before I graduate from high school so I can have a happy future with my partner.'
#
# '>>> Post: **hello there! itâs one of those nights where sleep seems to elude me. iâm looking for someone whoâs up for a chat to help pass the time.** **whether youâre in a different time zone, a fellow insomniac, or just a night owl, iâd [NAME] to connect. we can talk about anything - share stories, discuss interesting topics, or just engage in some light-hearted banter.** **if youâre also looking for some company through the night, feel free to send me a message. looking forward to some interesting conversations!**'
#
# '>>> Post: So I got my wrist sewn up to four days ago. the area is very messy and has vertical and horizontal cuts in different depths. now it has some brownish yellow discharge that smells very bad and im thinking if that is from the infection.'

# %% [markdown]
# # Preprocessing the data
# For both auto-regressive and masked language modeling, a common preprocessing step is to concatenate all the examples and then split the whole corpus into chunks of equal size. This is quite different from our usual approach, where we simply tokenize individual examples. Why concatenate everything together? The reason is that individual examples might get truncated if they’re too long, and that would result in losing information that might be useful for the language modeling task!

# %% [markdown]
# we’ll first tokenize our corpus as usual, but without setting the truncation=True option in our tokenizer. We’ll also grab the word IDs if they are available, as we will need them later on to do whole word masking. We’ll wrap this in a simple function, and while we’re at it we’ll remove the text and label columns since we don’t need them any longer:

# %%
def tokenize_function(examples):
    #examples["body"].remove("None,")
    #print(type(examples["body"]))
    result = tokenizer(examples["post"])

    if tokenizer.is_fast:
        result["word_ids"] = [result.word_ids(i) for i in range(len(result["input_ids"]))]
    return result


# Use batched=True to activate fast multithreading!
tokenized_datasets = dataset.map(
    tokenize_function, batched=True, remove_columns=['post','__index_level_0__']
)
tokenized_datasets
# Out:
# Map:   0%|          | 0/64744 [00:00<?, ? examples/s]
# Token indices sequence length is longer than the specified maximum sequence length for this model (851 > 512). Running this sequence through the model will result in indexing errors
# Dataset({
#     features: ['input_ids', 'token_type_ids', 'attention_mask', 'word_ids'],
#     num_rows: 64744
# })

# %%
tokenizer.model_max_length
# Out:
# 512

# %% [markdown]
# To show how the concatenation works, let’s take a few reviews from our tokenized training set and print out the number of tokens per review:

# %%
chunk_size = 128

# Slicing produces a list of lists for each feature
tokenized_samples = tokenized_datasets[:3]

for idx, sample in enumerate(tokenized_samples["input_ids"]):
    print(f"'>>> Post {idx} length: {len(sample)}'")
# Out:
# '>>> Post 0 length: 13'
# '>>> Post 1 length: 30'
# '>>> Post 2 length: 38'

# %% [markdown]
# We can then concatenate all these examples with a simple dictionary comprehension, as follows:

# %%
concatenated_examples = {
    k: sum(tokenized_samples[k], []) for k in tokenized_samples.keys()
}
total_length = len(concatenated_examples["input_ids"])
print(f"'>>> Concatenated reviews length: {total_length}'")
# Out:
# '>>> Concatenated reviews length: 81'

# %% [markdown]
# So now let’s split the concatenated reviews into chunks of the size given by block_size. To do so, we iterate over the features in concatenated_examples and use a list comprehension to create slices of each feature. The result is a dictionary of chunks for each feature:

# %%
chunks = {
    k: [t[i : i + chunk_size] for i in range(0, total_length, chunk_size)]
    for k, t in concatenated_examples.items()
}

for chunk in chunks["input_ids"]:
    print(f"'>>> Chunk length: {len(chunk)}'")
# Out:
# '>>> Chunk length: 81'

# %% [markdown]
# As you can see in this example, the last chunk will generally be smaller than the maximum chunk size. There are two main strategies for dealing with this:
#
# - Drop the last chunk if it’s smaller than chunk_size.
# - Pad the last chunk until its length equals chunk_size.
#
# We’ll take the first approach here, so let’s wrap all of the above logic in a single function that we can apply to our tokenized datasets:

# %%
def group_texts(examples):
    # Concatenate all texts
    concatenated_examples = {k: sum(examples[k], []) for k in examples.keys()}
    # Compute length of concatenated texts
    total_length = len(concatenated_examples[list(examples.keys())[0]])
    # We drop the last chunk if it's smaller than chunk_size
    total_length = (total_length // chunk_size) * chunk_size
    # Split by chunks of max_len
    result = {
        k: [t[i : i + chunk_size] for i in range(0, total_length, chunk_size)]
        for k, t in concatenated_examples.items()
    }
    # Create a new labels column
    result["labels"] = result["input_ids"].copy()
    return result

# %% [markdown]
# Note that in the last step of group_texts() we create a new labels column which is a copy of the input_ids one. As we’ll see shortly, that’s because in masked language modeling the objective is to predict randomly masked tokens in the input batch, and by creating a labels column we provide the ground truth for our language model to learn from.
#
# Let’s now apply group_texts() to our tokenized datasets using our trusty Dataset.map() function:

# %%
lm_datasets = tokenized_datasets.map(group_texts, batched=True)
lm_datasets
# Out:
# Map:   0%|          | 0/64744 [00:00<?, ? examples/s]
# Dataset({
#     features: ['input_ids', 'token_type_ids', 'attention_mask', 'word_ids', 'labels'],
#     num_rows: 56456
# })

# %% [markdown]
# You can see that grouping and then chunking the texts has produced many more examples than our original 25,000 for the train and test splits. That’s because we now have examples involving contiguous tokens that span across multiple examples from the original corpus. You can see this explicitly by looking for the special [SEP] and [CLS] tokens in one of the chunks:

# %%
tokenizer.decode(lm_datasets[1]["input_ids"])
# Out:
# '##ilify [SEP] [CLS] bid dosing of trintellix [SEP] [CLS] why do i get hallucinations 1h after taking my daily quetiapine? getting worse every day [SEP] [CLS] how much is too much? [SEP] [CLS] is this something i can talk to my new therapist about? [SEP] [CLS] diagnosticize me [SEP] [CLS] is it harmful to stay awake on seroquel xr? [SEP] [CLS] age - feel incredibly wound up and restless [SEP] [CLS] can you recommend resources to self - manage narcissism? [SEP] [CLS] ssri wirhdrawal and lsd personality changes... help please. [SEP] [CLS] feeling dysphoric'

# %% [markdown]
# In this example you can see two overlapping movie reviews, one about a high school movie and the other about homelessness. Let’s also check out what the labels look like for masked language modeling:

# %%
tokenizer.decode(lm_datasets[1]["labels"])
# Out:
# '##ilify [SEP] [CLS] bid dosing of trintellix [SEP] [CLS] why do i get hallucinations 1h after taking my daily quetiapine? getting worse every day [SEP] [CLS] how much is too much? [SEP] [CLS] is this something i can talk to my new therapist about? [SEP] [CLS] diagnosticize me [SEP] [CLS] is it harmful to stay awake on seroquel xr? [SEP] [CLS] age - feel incredibly wound up and restless [SEP] [CLS] can you recommend resources to self - manage narcissism? [SEP] [CLS] ssri wirhdrawal and lsd personality changes... help please. [SEP] [CLS] feeling dysphoric'

# %% [markdown]
# As expected from our group_texts() function above, this looks identical to the decoded input_ids — but then how can our model possibly learn anything? We’re missing a key step: inserting [MASK] tokens at random positions in the inputs! Let’s see how we can do this on the fly during fine-tuning using a special data collator.

# %% [markdown]
# # Fine-tuning BERT with the Trainer API

# %% [markdown]
# Fine-tuning a masked language model is almost identical to fine-tuning a sequence classification model. The only difference is that we need a special data collator that can randomly mask some of the tokens in each batch of texts. Fortunately, 🤗 Transformers comes prepared with a dedicated DataCollatorForLanguageModeling for just this task. We just have to pass it the tokenizer and an mlm_probability argument that specifies what fraction of the tokens to mask. We’ll pick 15%, which is the amount used for BERT and a common choice in the literature:

# %%
from transformers import DataCollatorForLanguageModeling

data_collator = DataCollatorForLanguageModeling(tokenizer=tokenizer, mlm_probability=0.15)

# %% [markdown]
# To see how the random masking works, let’s feed a few examples to the data collator. Since it expects a list of dicts, where each dict represents a single chunk of contiguous text, we first iterate over the dataset before feeding the batch to the collator. We remove the "word_ids" key for this data collator as it does not expect it:

# %%
samples = [lm_datasets[i] for i in range(2)]
for sample in samples:
    _ = sample.pop("word_ids")

for chunk in data_collator(samples)["input_ids"]:
    print(f"\n'>>> {tokenizer.decode(chunk)}'")
# Out:
# '>>> [CLS] new providers wonat prescribe [MASK] medication. why? [SEP] [CLS] [ age [MASK] [MASK] was prescribed risperidone, quetiapine and olanzapine. what ' [MASK] [MASK] better alternative for these? [SEP] [CLS] m33 i am currently on 20 mg [MASK]citalo [MASK]am for gad and it killed my sex drive please suggest how can i reduce or reverse ssri sexual [MASK] effects? [SEP] [CLS] is this appropriate [MASK] from a psychiatrist? [SEP] [CLS] disorder where you [MASK] perpetually targeted by a real person? [SEP] [CLS] how long do thoughts to self destruct [MASK] after starting antide [MASK] [MASK] [SEP] [CLS] outside studying [SEP] [CLS] ab'
#
# '>>> ##ilify [SEP] [CLS] biddiniing of trintellix [SEP] [CLS] why [MASK] i [MASK] hallucinations 1h after taking my daily quetiapine? getting worse every day [SEP] [CLS] how much is too much? [SEP] [CLS] is this something [MASK] can talk to my new therapist about [MASK] [SEP] [CLS] diagnosticize me [SEP] [CLS] is it harmful to stay awake on seroquel xr? [SEP] [CLS] age - [MASK] incredibly wound up [MASK] [MASK] [SEP] [CLS] can you lyndon resources to self [MASK] manage narcissism? [SEP] [CLS] [MASK]i [MASK]rhdra [MASK] [MASK] lsd personality changes... help please [MASK] [SEP] [CLS] feeling dys [MASK]oric'

# %% [markdown]
# Nice, it worked! We can see that the [MASK] token has been randomly inserted at various locations in our text. These will be the tokens which our model will have to predict during training — and the beauty of the data collator is that it will randomize the [MASK] insertion with every batch!

# %% [markdown]
# When training models for masked language modeling, one technique that can be used is to mask whole words together, not just individual tokens. This approach is called whole word masking. If we want to use whole word masking, we will need to build a data collator ourselves. A data collator is just a function that takes a list of samples and converts them into a batch, so let’s do this now! We’ll use the word IDs computed earlier to make a map between word indices and the corresponding tokens, then randomly decide which words to mask and apply that mask on the inputs. Note that the labels are all -100 except for the ones corresponding to mask words.

# %%
import pandas as pd

df = pd.read_csv('lexicon_words.txt', sep=" ", header=None)
lexicon_words = df[0].values.tolist()
print(len(lexicon_words))
#lexicon_words = " ".join(lexicon_words)
#print(lexicon_words)
lexicon_words1 = tokenizer(lexicon_words)
#print(len(lexicon_words1["input_ids"]))
try:
    lexicon_words1["input_ids"].remove(int(101))
    lexicon_words1["input_ids"].remove(int(102))
except:
    pass
print(len(lexicon_words1["input_ids"]))
# Out:
# 7545
# 7545

# %%
import collections
import numpy as np

from transformers import default_data_collator

wwm_probability = 0.2


#def whole_word_masking_data_collator(features, lexicon):
def whole_word_masking_data_collator(features):
    df = pd.read_csv('lexicon_words.txt', sep=" ", header=None)
    lexicon_words = df[0].values.tolist()
    #print(len(lexicon_words))
    #lexicon_words = " ".join(lexicon_words)
    #print(lexicon_words)
    lexicon_words1 = tokenizer(lexicon_words)
    #print(len(lexicon_words1["input_ids"]))
    try:
        lexicon_words1["input_ids"].remove(int(101))
        lexicon_words1["input_ids"].remove(int(102))
    except:
        pass
    #print(len(lexicon_words1["input_ids"]))
    lexicon = lexicon_words1["input_ids"]
    #############################################################
    #print(features)
    for feature in features:
        word_ids = feature.pop("word_ids")
        #print(word_ids)

        # Create a map between words and corresponding token indices
        mapping = collections.defaultdict(list)
        current_word_index = -1
        current_word = None
        mask = []
        for idx, (word_id,inp) in enumerate(zip(word_ids,feature["input_ids"])):
            #print(idx,word_id,inp)
            if word_id is not None:
                if word_id != current_word:
                    current_word = word_id
                    current_word_index += 1
                    if inp in lexicon: #Mask words in the lexicon
                        mask.append(1) #
                    else:              #
                        mask.append(0) #
                mapping[current_word_index].append(idx)
        #print(mapping[current_word_index])

        # Randomly mask words
        mask_len = np.random.binomial(1, wwm_probability, (len(mapping),))
        #print(len(mask_len))
        input_ids = feature["input_ids"]
        #print(len(input_ids))
        labels = feature["labels"]
        #print(len(labels))
        new_labels = [-100] * len(labels)

        #Calculate the % difference for the masking
        mask = np.array(mask)
        len_count = np.count_nonzero(mask_len == 1)
        mask_count = np.count_nonzero(mask == 1)
        #print(len_count,mask_count)

        if len_count == 0:
            #mask_len = np.random.binomial(1, wwm_probability, (len(mapping),))
            #len_count = np.count_nonzero(mask_len == 1)
            len_count = 15
            print("len value = 0")
        else:
            pass

        x = len_count-mask_count
        #print(x)
        #print(len_count)
        xy = x/len_count
        #print(xy)
        yy = wwm_probability*xy
        #print((yy))

        #Random mask the rest of values
        mask_2 = np.random.binomial(1, yy, (len(mapping),))
        #print(len(mask),len(mask_2))
        new_mask = mask + mask_2
        new_mask = np.where(new_mask > 1, 1, new_mask)

        for word_id in np.where(new_mask)[0]:
            word_id = word_id.item()
            #print(word_id)
            for idx in mapping[word_id]:
                #print(idx)
                new_labels[idx] = labels[idx]
                input_ids[idx] = tokenizer.mask_token_id
                #print(input_ids[idx])
    #df.close()
    return default_data_collator(features)

# %% [markdown]
# Next, we can try it on the same samples as before:

# %%
samples = [lm_datasets[i] for i in range(2)]
batch = whole_word_masking_data_collator(samples)
#batch = whole_word_masking_data_collator(samples,lexicon_words1["input_ids"])

for chunk in batch["input_ids"]:
    print(f"\n'>>> {tokenizer.decode(chunk)}'")
# Out:
# '>>> [CLS] new providers wonat prescribe my medication. [MASK]? [SEP] [CLS] [ age ] i was prescribed risperidone, quetiapine and olanzapine [MASK] [MASK] ' s a better alternative for [MASK] [MASK] [SEP] [CLS] m33 [MASK] am currently on 20 mg escitalopram for [MASK] [MASK] and [MASK] killed my sex drive please [MASK] how [MASK] [MASK] reduce or reverse ssri sexual side effects? [SEP] [CLS] is [MASK] appropriate behaviour from a psychiatrist? [SEP] [CLS] disorder where [MASK] feel perpetually targeted by a real [MASK]? [SEP] [CLS] how long [MASK] thoughts to self destruct last after [MASK] antidepressants [SEP] [CLS] outside studying [SEP] [CLS] ab'
#
# '>>> ##ilify [SEP] [CLS] bid dosing of trintellix [SEP] [CLS] [MASK] [MASK] i [MASK] hallucinations 1h after taking my daily quetiapine [MASK] getting worse every [MASK] [SEP] [CLS] how much is [MASK] much? [SEP] [CLS] is this something i can talk to my new [MASK] about? [SEP] [CLS] diagnosticize me [SEP] [CLS] is it harmful to stay awake on [MASK] [MASK] [MASK] xr? [SEP] [CLS] age - [MASK] incredibly wound [MASK] and restless [SEP] [CLS] can you [MASK] resources to self - manage narcissism? [SEP] [CLS] ssri [MASK] [MASK] [MASK] [MASK] and lsd personality changes. [MASK] [MASK] help please. [SEP] [CLS] [MASK] dysphoric'

# %% [markdown]
# Now that we have two data collators, the rest of the fine-tuning steps are standard. Training can take a while on Google Colab if you’re not lucky enough to score a mythical P100 GPU 😭, so we’ll first downsample the size of the training set to a few thousand examples. Don’t worry, we’ll still get a pretty decent language model! A quick way to downsample a dataset in 🤗 Datasets is via the Dataset.train_test_split() function

# %%
train_size = 50_000
test_size = int(0.1 * train_size)

downsampled_dataset = lm_datasets.train_test_split(
    train_size=train_size, test_size=test_size, seed=42
)
downsampled_dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'word_ids', 'labels'],
#         num_rows: 50000
#     })
#     test: Dataset({
#         features: ['input_ids', 'token_type_ids', 'attention_mask', 'word_ids', 'labels'],
#         num_rows: 5000
#     })
# })

# %% [markdown]
# This has automatically created new train and test splits, with the training set size set to 10,000 examples and the validation set to 10% of that — feel free to increase this if you have a beefy GPU! The next thing we need to do is log in to the Hugging Face Hub. If you’re running this code in a notebook, you can do so with the following utility function:

# %%
# from huggingface_hub import notebook_login

# notebook_login()

# %%
# Alternativa: log in desde terminal

#! python -c "from huggingface_hub import login; login(token='PEGA_AQUI_TU_TOKEN_WRITE')"

# %%
# !git config --global credential.helper store

# %% [markdown]
# Once we’re logged in, we can specify the arguments for the Trainer:

# %%
from transformers import TrainingArguments

batch_size = 16
# Show the training loss with every epoch
logging_steps = len(downsampled_dataset) // batch_size
print(len(downsampled_dataset))
model_name = model_checkpoint.split("/")[-1]

training_args = TrainingArguments(
    output_dir=f"{model_name}-finetuned-selfharm",
    # overwrite_output_dir=True,
    # evaluation_strategy="epoch",
    eval_strategy="epoch",
    learning_rate=2e-5,
    weight_decay=0.01,
    per_device_train_batch_size=batch_size,
    per_device_eval_batch_size=batch_size,
    push_to_hub=False, ################## HUB
    fp16=True,
    logging_steps=50,
    remove_unused_columns=False,
)
# Out:
# 2

# %% [markdown]
# Here we tweaked a few of the default options, including logging_steps to ensure we track the training loss with each epoch. We’ve also used fp16=True to enable mixed-precision training, which gives us another boost in speed. By default, the Trainer will remove any columns that are not part of the model’s forward() method. This means that if you’re using the whole word masking collator, you’ll also need to set remove_unused_columns=False to ensure we don’t lose the word_ids column during training.
#
# Note that you can specify the name of the repository you want to push to with the hub_model_id argument (in particular, you will have to use this argument to push to an organization). For instance, when we pushed the model to the huggingface-course organization, we added hub_model_id="huggingface-course/distilbert-finetuned-imdb" to TrainingArguments. By default, the repository used will be in your namespace and named after the output directory you set, so in our case it will be "lewtun/distilbert-finetuned-imdb".
#
# We now have all the ingredients to instantiate the Trainer. Here we just use the standard data_collator, but you can try the whole word masking collator and compare the results as an exercise:

# %%
from transformers import Trainer

trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=downsampled_dataset["train"],
    eval_dataset=downsampled_dataset["test"],
    data_collator=whole_word_masking_data_collator,
)

# %% [markdown]
# Unlike other tasks like text classification or question answering where we’re given a labeled corpus to train on, with language modeling we don’t have any explicit labels. So how do we determine what makes a good language model? Like with the autocorrect feature in your phone, a good language model is one that assigns high probabilities to sentences that are grammatically correct, and low probabilities to nonsense sentences. To give you a better idea of what this looks like, you can find whole sets of “autocorrect fails” online, where the model in a person’s phone has produced some rather funny (and often inappropriate) completions!
#
# Assuming our test set consists mostly of sentences that are grammatically correct, then one way to measure the quality of our language model is to calculate the probabilities it assigns to the next word in all the sentences of the test set. High probabilities indicates that the model indicates that the model is not “surprised” or “perplexed” by the unseen examples, and suggests it has learned the basic patterns of grammar in the language. There are various mathematical definitions of perplexity, but the one we’ll use defines it as the exponential of the cross-entropy loss. Thus, we can calculate the perplexity of our pretrained model by using the model.evaluate() method to compute the cross-entropy loss on the test set and then taking the exponential of the result:

# %%
import math
import torch
import gc

gc.collect()
torch.cuda.empty_cache()

# eval_results = trainer.evaluate()
# print(f">>> Perplexity: {math.exp(eval_results['eval_loss']):.2f}")

# %%
#torch.cuda.memory_summary(device=None, abbreviated=False)

# %% [markdown]
# A lower perplexity score means a better language model, and we can see here that our starting model has a somewhat large value. Let’s see if we can lower it by fine-tuning! To do that, we first run the training loop:

# %%
trainer.train()
# Out:
#     <div>
#
#       <progress value='9375' max='9375' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [9375/9375 1:39:20, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Epoch</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>1</td>
#       <td>0.518959</td>
#       <td>0.495459</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.516269</td>
#       <td>0.483979</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.487534</td>
#       <td>0.478685</td>
#     </tr>
#   </tbody>
# </table><p>
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# TrainOutput(global_step=9375, training_loss=0.521603910929362, metrics={'train_runtime': 5961.359, 'train_samples_per_second': 25.162, 'train_steps_per_second': 1.573, 'total_flos': 9870180480000000.0, 'train_loss': 0.521603910929362, 'epoch': 3.0})

# %% [markdown]
# and then compute the resulting perplexity on the test set as before:

# %%
# eval_results = trainer.evaluate()
# print(f">>> Perplexity: {math.exp(eval_results['eval_loss']):.2f}")

# %% [markdown]
# Once training is finished, we can push the model card with the training information to the Hub (the checkpoints are saved during training itself):

# %%
#!git config --global credential.helper store
#notebook_login()

# %%
#trainer.push_to_hub()
trainer.save_model(f"./{model_name}-finetuned-selfharm")
# Out:
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
tokenizer.save_pretrained(f"./{model_name}-finetuned-selfharm")
# Out:
# ('./bert-base-uncased-finetuned-selfharm/tokenizer_config.json',
#  './bert-base-uncased-finetuned-selfharm/tokenizer.json')

# %% [markdown]
# # Using our fine-tuned model

# %% [markdown]
# You can interact with your fine-tuned model either by using its widget on the Hub or locally with the pipeline from 🤗 Transformers. Let’s use the latter to download our model using the fill-mask pipeline:

# %%
from transformers import pipeline
from transformers import AutoModelForSequenceClassification

#state_dict = torch.load(f"./{model_name}-finetuned-redditEzra", map_location="cpu")

mask_filler = pipeline(
    "fill-mask", model=f"{model_name}-finetuned-selfharm/")


#new_model = AutoModelForSequenceClassification.from_pretrained(f"./{model_name}-finetuned-redditEzra")
# Out:
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]

# %% [markdown]
# We can then feed the pipeline our sample text of “This is a great [MASK]” and see what the top 5 predictions are:

# %%
text = "I used to be able to [MASK]."

preds = mask_filler(text)

for pred in preds:
    print(f">>> {pred['sequence']}")
# Out:
# >>> i used to be able to talk.
# >>> i used to be able to heal.
# >>> i used to be able to sleep.
# >>> i used to be able to cope.
# >>> i used to be able to read.

# %% [markdown]
# # Upload to HF Hub

# %%
from transformers import AutoModelForMaskedLM, AutoTokenizer

repo_id = "andreslilloortiz/SHBERT-de-biased"

# 1. Cargar explicitamente lo que hay en la carpeta
modelo_guardado = AutoModelForMaskedLM.from_pretrained(f"./{model_name}-finetuned-selfharm")
tokenizador_guardado = AutoTokenizer.from_pretrained(f"./{model_name}-finetuned-selfharm")

# 2. Subir al Hub
modelo_guardado.push_to_hub(repo_id)
tokenizador_guardado.push_to_hub(repo_id)

print("¡Modelo y tokenizador subidos con éxito!")
# Out:
# Loading weights:   0%|          | 0/202 [00:00<?, ?it/s]
# Writing model shards:   0%|          | 0/1 [00:00<?, ?it/s]
# Processing Files (0 / 0): |          |  0.00B /  0.00B
# New Data Upload: |          |  0.00B /  0.00B
# README.md: 0.00B [00:00, ?B/s]
# ¡Modelo y tokenizador subidos con éxito!
